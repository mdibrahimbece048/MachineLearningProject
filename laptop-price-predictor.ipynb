# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('laptop_data.csv')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
# checking if two rows are identical
df.duplicated().sum()
# if 0 it means threre is no duplicated rows
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
# dropping Unnnamed column
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
# Removing GB from Ram Columns
df['Ram']=df['Ram'].apply(lambda x:x.replace('GB',''))

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
# Rmoving kg from column weight
df['Weight']=df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df.info()
# still Ram and weight are object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
# converting Ram and Object into int datatype
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %% [markdown]
# # EDA Analysis

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])
####### Price data is squied
# Out:
# C:\Users\bat17\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# checking relation between company name and price
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# checking average price value with respect to Typename
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# C:\Users\bat17\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='Price'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
df.sample(5)
# Out:
#       Company   TypeName  Inches                  ScreenResolution  \
# 500      Asus    Netbook    11.6                          1366x768
# 57       Asus   Notebook    15.6                          1366x768
# 430   Samsung    Netbook    11.6                          1366x768
# 1172     Asus   Notebook    15.6                          1366x768
# 540      Dell  Ultrabook    13.3  Quad HD+ / Touchscreen 3200x1800
#
#                                        Cpu  Ram              Memory  \
# 500   Intel Celeron Dual Core N3350 1.1GHz    4  64GB Flash Storage
# 57              Intel Core i5 7200U 2.5GHz    4           256GB SSD
# 430   Intel Celeron Dual Core N3060 1.6GHz    4  16GB Flash Storage
# 1172  Intel Celeron Dual Core N3050 1.6GHz    4           500GB HDD
# 540             Intel Core i7 8550U 1.8GHz    8           256GB SSD
#
#                          Gpu         OpSys  Weight       Price  Touchscreen
# 500    Intel HD Graphics 500  Windows 10 S    1.20  18115.2000            0
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Ips']=df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['ScreenResolution'].str.split('x')
# Out:
# 0               [IPS Panel Retina Display 2560, 1600]
# 1                                         [1440, 900]
# 2                                [Full HD 1920, 1080]
# 3               [IPS Panel Retina Display 2880, 1800]
# 4               [IPS Panel Retina Display 2560, 1600]
#                             ...
# 1298     [IPS Panel Full HD / Touchscreen 1920, 1080]
# 1299    [IPS Panel Quad HD+ / Touchscreen 3200, 1800]
# 1300                                      [1366, 768]
# 1301                                      [1366, 768]
# 1302                                      [1366, 768]
# Name: ScreenResolution, Length: 1303, dtype: object

# %%
new=df['ScreenResolution'].str.split('x',n=1,expand=True)
new
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
new[0]
# Out:
# 0               IPS Panel Retina Display 2560
# 1                                        1440
# 2                                Full HD 1920
# 3               IPS Panel Retina Display 2880
# 4               IPS Panel Retina Display 2560
#                         ...
# 1298     IPS Panel Full HD / Touchscreen 1920
# 1299    IPS Panel Quad HD+ / Touchscreen 3200
# 1300                                     1366
# 1301                                     1366
# 1302                                     1366
# Name: 0, Length: 1303, dtype: object

# %%
new[1]
# Out:
# 0       1600
# 1        900
# 2       1080
# 3       1800
# 4       1600
#         ...
# 1298    1080
# 1299    1800
# 1300     768
# 1301     768
# 1302     768
# Name: 1, Length: 1303, dtype: object

# %%
df['x_res']=new[0]
df['y_res']=new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
type(df['x_res'][0])
# Out:
# str

# %%
df['x_res']
# Out:
# 0               IPS Panel Retina Display 2560
# 1                                        1440
# 2                                Full HD 1920
# 3               IPS Panel Retina Display 2880
# 4               IPS Panel Retina Display 2560
#                         ...
# 1298     IPS Panel Full HD / Touchscreen 1920
# 1299    IPS Panel Quad HD+ / Touchscreen 3200
# 1300                                     1366
# 1301                                     1366
# 1302                                     1366
# Name: x_res, Length: 1303, dtype: object

# %%
type(df['x_res'][0])
# Out:
# str

# %%
df['x_res']=df['x_res'].apply(lambda x:x.split())

# %%
L=[]
for i in range(len(df['x_res'])):
    L.append(df['x_res'][i][-1])

# %%
L
# Out:
# ['2560',
#  '1440',
#  '1920',
#  '2880',
#  '2560',
#  '1366',
#  '2880',
#  '1440',
#  '1920',
#  '1920',
#  '1366',
#  '1920',
#  '2880',
#  '1920',
#  '2304',
#  '2560',
#  '1920',
#  '2880',
#  '1920',
#  '1920',
#  '1366',
#  '1920',
#  '1366',
#  '1920',
#  '1920',
#  '1366',
#  '1440',
#  '1920',
#  '1920',
#  '1920',
#  '1920',
#  '1366',
#  '1920',
#  '3200',
#  '1440',
#  '1366',
#  '1366',
#  '1920',
#  '1366',
#  '1920',
#  '1920',
#  '1920',
#  '1366',
#  '1920',
#  '1920',
#  '2560',
#  '1366',
#  '1920',
#  '1920',
#  '1366',
#  '1920',
#  '1920',
#  '1920',
#  '1920',
#  '1366',
#  '1920',
#  '1920',
#  '1366',
#  '1920',
#  '1920',
#  '1920',
#  '1920',
#  '1920',
#  '1920',
#  '1920',
#  '1920',
#  '1366',
#  '1366',
#  '1920',
#  '1920',
#  '2256',
#  '1920',
#  '1920',
#  '1920',
#  '1366',
#  '1920',
#  '1920',
#  '1920',
#  '1920',
#  '1920',
#  '1920',
#  '2304',
#  '1920',
#  '1920',
#  '1366',
#  '1920',
#  '1920',
#  '1920',
#  '1920',
#  '1920',
# ...

# %%
df['x_res']=L

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  x_res             1303 non-null   object
#  14  y_res             1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# ...

# %%
df['x_res']=df['x_res'].astype('int32')
df['y_res']=df['y_res'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  x_res             1303 non-null   int32
#  14  y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  x_res             1303 non-null   int32
#  14  y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# x_res          0.556529
# y_res          0.552809
# Name: Price, dtype: float64

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['Ppi']=((df['x_res']**2)+(df['y_res']**2))**0.5/df['Inches']

# %%
df.drop(columns=['ScreenResolution'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips  x_res  y_res         Ppi
# 0   71378.6832            0    1   2560   1600  226.983005
# 1   47895.5232            0    0   1440    900  127.677940
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu'].apply(lambda x:x.split())
# Out:
# 0                         [Intel, Core, i5, 2.3GHz]
# 1                         [Intel, Core, i5, 1.8GHz]
# 2                  [Intel, Core, i5, 7200U, 2.5GHz]
# 3                         [Intel, Core, i7, 2.7GHz]
# 4                         [Intel, Core, i5, 3.1GHz]
#                            ...
# 1298               [Intel, Core, i7, 6500U, 2.5GHz]
# 1299               [Intel, Core, i7, 6500U, 2.5GHz]
# 1300    [Intel, Celeron, Dual, Core, N3050, 1.6GHz]
# 1301               [Intel, Core, i7, 6500U, 2.5GHz]
# 1302    [Intel, Celeron, Dual, Core, N3050, 1.6GHz]
# Name: Cpu, Length: 1303, dtype: object

# %%
df['Cpu Name']=df['Cpu'].apply(lambda x:x.split()[0:3])
df['Cpu Name']
# Out:
# 0            [Intel, Core, i5]
# 1            [Intel, Core, i5]
# 2            [Intel, Core, i5]
# 3            [Intel, Core, i7]
# 4            [Intel, Core, i5]
#                  ...
# 1298         [Intel, Core, i7]
# 1299         [Intel, Core, i7]
# 1300    [Intel, Celeron, Dual]
# 1301         [Intel, Core, i7]
# 1302    [Intel, Celeron, Dual]
# Name: Cpu Name, Length: 1303, dtype: object

# %%
df['Cpu Name']=df['Cpu Name'].apply(lambda x:' '.join(x))
df['Cpu Name']
# Out:
# 0            Intel Core i5
# 1            Intel Core i5
# 2            Intel Core i5
# 3            Intel Core i7
# 4            Intel Core i5
#                ...
# 1298         Intel Core i7
# 1299         Intel Core i7
# 1300    Intel Celeron Dual
# 1301         Intel Core i7
# 1302    Intel Celeron Dual
# Name: Cpu Name, Length: 1303, dtype: object

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips  x_res  y_res         Ppi       Cpu Name
# 0   71378.6832            0    1   2560   1600  226.983005  Intel Core i5
# ...

# %%
def fetch_processor(text):
    if text=='Intel Core i7' or text=='Intel Core i5' or text=='Intel Core i3':
        return text
    else:
        if text.split()[0]=='Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu Brand']=df['Cpu Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips  x_res  y_res         Ppi       Cpu Name  \
# 0   71378.6832            0    1   2560   1600  226.983005  Intel Core i5
# ...

# %%
df['Cpu Brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Cpu Brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
def fetch_SsdType(text):
    if 'SSD' in text:
        return text.replace('SSD','')

# %%
df['Ssd Type']=df['Memory'].apply(fetch_SsdType)
df['Ssd Type']
# Out:
# 0       128GB
# 1         None
# 2       256GB
# 3       512GB
# 4       256GB
#          ...
# 1298    128GB
# 1299    512GB
# 1300      None
# 1301      None
# 1302      None
# Name: Ssd Type, Length: 1303, dtype: object

# %%
def fetch_HddType(text):
    if 'HDD' in text:
        return text.replace('HDD','')

# %%
df['Hdd Type']=df['Memory'].apply(fetch_HddType)
df['Hdd Type']
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#          ...
# 1298      None
# 1299      None
# 1300      None
# 1301      1TB
# 1302    500GB
# Name: Hdd Type, Length: 1303, dtype: object

# %%
def fetch_flashstorage(text):
    if 'Flash Storage' in text:
        return text.replace('Flash Storage','')

# %%
df['Flash Storage Type']=df['Memory'].apply(fetch_flashstorage)
df['Flash Storage Type']
# Out:
# 0         None
# 1       128GB
# 2         None
# 3         None
# 4         None
#          ...
# 1298      None
# 1299      None
# 1300     64GB
# 1301      None
# 1302      None
# Name: Flash Storage Type, Length: 1303, dtype: object

# %%
def fetch_Hybrid(text):
    if 'Hybrid' in text:
        return text.replace('Hybrid','')

# %%
df['Hybrid Type']=df['Memory'].apply(fetch_Hybrid)

# %%
df['Hybrid Type']
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 1298    None
# 1299    None
# 1300    None
# 1301    None
# 1302    None
# Name: Hybrid Type, Length: 1303, dtype: object

# %%
df.sample(5)
# Out:
#     Company            TypeName  Inches                         Cpu  Ram  \
# 881      HP  2 in 1 Convertible    15.6  Intel Core i5 7200U 2.5GHz    4
# 774      HP           Ultrabook    12.5  Intel Core i5 6200U 2.3GHz    4
# 903  Lenovo           Ultrabook    14.0  Intel Core i7 7500U 2.7GHz    8
# 991      HP            Notebook    15.6    Intel Core i3 6006U 2GHz    4
# 795  Lenovo  2 in 1 Convertible    14.0  Intel Core i5 7200U 2.5GHz    8
#
#                    Memory                    Gpu       OpSys  Weight  \
# 881             500GB HDD  Intel HD Graphics 620  Windows 10    2.30
# 774             256GB SSD  Intel HD Graphics 520  Windows 10    1.26
# 903   256GB Flash Storage  Intel HD Graphics 620  Windows 10    1.13
# 991  128GB SSD +  1TB HDD         AMD Radeon 520  Windows 10    2.10
# 795             256GB SSD  Intel HD Graphics 620  Windows 10    1.42
#
#           Price  ...  Ips  x_res  y_res         Ppi       Cpu Name  \
# ...

# %%
df.drop(columns=['Memory'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#    x_res  y_res         Ppi       Cpu Name      Cpu Brand Ssd Type Hdd Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company             1303 non-null   object
#  1   TypeName            1303 non-null   object
#  2   Inches              1303 non-null   float64
#  3   Cpu                 1303 non-null   object
#  4   Ram                 1303 non-null   int32
#  5   Gpu                 1303 non-null   object
#  6   OpSys               1303 non-null   object
#  7   Weight              1303 non-null   float32
#  8   Price               1303 non-null   float64
#  9   Touchscreen         1303 non-null   int64
#  10  Ips                 1303 non-null   int64
#  11  x_res               1303 non-null   int32
#  12  y_res               1303 non-null   int32
#  13  Ppi                 1303 non-null   float64
#  14  Cpu Name            1303 non-null   object
# ...

# %%
df['Ssd Type']=df['Ssd Type'].astype('str')

# %%
df['Ssd Type']=df['Ssd Type'].apply(lambda x:x.replace('GB',''))

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches                          Cpu  Ram  \
# 1069   Apple  Ultrabook    12.0          Intel Core M 1.1GHz    8
# 62    Lenovo   Notebook    14.0   Intel Core i3 7130U 2.7GHz    8
# 852     Dell   Notebook    17.3   Intel Core i7 7500U 2.7GHz    8
# 1066    Asus     Gaming    17.3  Intel Core i7 6820HK 2.7GHz   64
# 284     Acer   Notebook    15.6   Intel Core i7 8550U 1.8GHz    8
#
#                           Gpu       OpSys  Weight      Price  Touchscreen  \
# 1069    Intel HD Graphics 515    Mac OS X    0.92   69264.00            0
# 62      Intel HD Graphics 620       No OS    1.70   31914.72            0
# 852        AMD Radeon R7 M445       Linux    2.83   46087.20            0
# 1066  Nvidia GeForce GTX 980   Windows 10    3.58  211788.00            0
# 284      Nvidia GeForce MX150  Windows 10    3.00   50669.28            0
#
#       Ips  x_res  y_res         Ppi       Cpu Name              Cpu Brand  \
# ...

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\bat17\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\bat17\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
x=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
x.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                             Gpu  OpSys  Weight  Touchscreen  Ips  x_res  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37            0    1   2560
# 1        Intel HD Graphics 6000  macOS    1.34            0    0   1440
# 2         Intel HD Graphics 620  No OS    1.86            0    0   1920
# 3            AMD Radeon Pro 455  macOS    1.83            0    1   2880
# 4  Intel Iris Plus Graphics 650  macOS    1.37            0    1   2560
#
#    y_res         Ppi       Cpu Name      Cpu Brand Ssd Type Hdd Type  \
# 0   1600  226.983005  Intel Core i5  Intel Core i5     128      None
# ...

# %%
y.head()
# Out:
# 0    11.175755
# 1    10.776777
# 2    10.329931
# 3    11.814476
# 4    11.473101
# Name: Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split as tts
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.2)
x_train
# Out:
#       Company     TypeName  Inches                                   Cpu  Ram  \
# 561    Lenovo     Notebook    15.6            Intel Core i3 7130U 2.7GHz    4
# 901      Asus       Gaming    17.3           Intel Core i7 6820HK 2.7GHz   32
# 1292     Dell     Notebook    15.6  Intel Celeron Dual Core N3050 1.6GHz    2
# 861        HP     Notebook    15.6            Intel Core i5 7300U 2.6GHz    8
# 702    Lenovo     Notebook    15.6           AMD A12-Series 9720P 3.6GHz    8
# ...       ...          ...     ...                                   ...  ...
# 1168       HP     Notebook    14.0  Intel Celeron Dual Core N3060 1.6GHz    2
# 131      Dell     Notebook    15.6              Intel Core i3 6006U 2GHz    4
# 1145       HP  Workstation    15.6           Intel Core i7 6700HQ 2.6GHz    8
# 1071       HP     Notebook    15.6            Intel Core i5 6200U 2.3GHz    4
# 1042  Toshiba     Notebook    15.6            Intel Core i7 6500U 2.5GHz   16
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

# %%
# Importing scklearn algorithm
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostClassifier,GradientBoostingClassifier,ExtraTreesRegressor
from sklearn.svm import SVR

# %%
step1= ColumnTransformer(transformers=[
     ('col_tnf',OneHotEncoder(sparse=True,drop='first'),[0,1,3,5,6,-1,-2,-3,-4,-5])
 ],remainder='passthrough')

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches                   Cpu  Ram  \
# 0   Apple  Ultrabook    13.3  Intel Core i5 2.3GHz    8
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
#
#    x_res  y_res         Ppi       Cpu Name      Cpu Brand Ssd Type Hdd Type  \
# 0   2560   1600  226.983005  Intel Core i5  Intel Core i5     128      None
#
#   Flash Storage Type Hybrid Type
# 0               None        None

# %%
step2=LinearRegression()
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py in _hstack(self, Xs)
#     777                 # dtype conversion if necessary.
# --> 778                 converted_Xs = [
#     779                     check_array(X, accept_sparse=True, force_all_finite=False)
#
# ~\anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py in <listcomp>(.0)
#     778                 converted_Xs = [
# --> 779                     check_array(X, accept_sparse=True, force_all_finite=False)
#     780                     for X in Xs
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     745                 else:
# ...
